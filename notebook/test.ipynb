# %%
from dbnl_bear import parse
parse.dbnl_to_txt("dbnl_xml")
# Out:
# Directory dbnl_txt_files already exists
# 100%|██████████| 3/3 [00:00<00:00, 17.37it/s]

# %%
# Create a .env file
with open(".env", "w") as f:
    f.write("{API_key_here}\n")

# %%
from dbnl_bear import ai_read
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
result = await ai_read.analyze_document("dbnl_txt_files/_lev021leve01.txt", "cheese")
print(result)
# Out:
# 100%|██████████| 2986/2986 [01:22<00:00, 36.24it/s]
# [CheeseInText(explanation='The sentence discusses the life of St. Begga, the Duchess of Brabant, and her connection to the Beguines, but it does not mention cheese or any related topics. Therefore, it is not relevant to research focused on cheese.', judgement=False, original_sentence="S. Begga Ducissa Brabantiae fundatrix Begginarum. Th. van Merlen\n\nHET LEVEN Van de seer Edele Doorluchtighste\n\nEN\n\nH. BEGGA\n\nHERTOGINNE VAN BRABANT,\n\nStightersse der Beggynnen.\n\nMET\n\nEen Cort Begryp van de Levens der Salige,\n\nGodtvruchtige en Lof-weerdige\n\nBEGGYNTJENS\n\nDer Vermaerde en Hoogh-gepresen Beggyn-\n\nHoven, by een vergadert door eenen\n\nonbekenden Dienaer Godts.\n\nt'ANTWERPEN,"), CheeseInText(explanation='The given sentence is an address or introduction likely related to a publication, mentioning a widow and various respectable women, but does not contain any information about cheese or its cultural significance.', judgement=False, original_sentence="t'ANTWERPEN,\n\nBy de Weduwe van Petrus Jacobs, woonende\n\ninde corte Nieuw-straet, inder witten Leeuw. 1712.\n\nMet Approbatie ende Privilegie.\n\nAen alle de eerwaardige vrouwen groot Jouffrouwen oversten, alle Jouffrouwen kerck-meesterssen, der krancken, der Conventen van de respective volgende vermaerde Beggyn-hoven, mitsgaders alle seer weerdige Beggyntjes.\n\nSEER EERWEERDIGE JOUFFROUWEN"), CheeseInText(explanation='The sentence discusses theological concepts and the role of humans in relation to God, but it does not mention cheese or provide any relevant information about it.', judgement=False, original_sentence='TEn compt maer Godt alleen toe met een woort alle saecken in sijn volmaecktheyt te stellen: daerom als de menschen sijn schepsels, jet willen aenvatten, moeten van hem hulp versoeken, en hunnen aerbeyt vervoegen by sijnen uytwerckenden wille. Den Seer Eerweerdigen Heer Joseph Geldolph van Rijckel. Abt der Edele en Wydt beroemde Abdye van Sinte Geertruyt binnen de Stadt en Universiteydt van Loven,'), CheeseInText(explanation='The sentence discusses religious figures and their history, specifically mentioning St. Begga and St. Gertrude, but it does not reference cheese or any related topics. Therefore, it is not relevant to cheese research.', judgement=False, original_sentence="van Loven, heeft begost en opgesocht de Heylighe, Salige en in godtvruchtigheyt vermaerde Beggyntjens, ende gestelt achter het wonderlijck en Heyligh leven, dat hy beschreven heeft (al in't latijn) van hun eerste Stightersse de H. Begga, Hertoginne van Brabant Suster van sijn Princersse en Patronersse de H. Geertruydt Abdisse van Nijvel: ende midts den vernoemden Abt nu al ontrent de 70. jaeren"), CheeseInText(explanation='The sentence discusses historical figures and their actions, but it does not mention cheese or related topics.', judgement=False, original_sentence='de 70. jaeren doot is, en sedert desgelijcke van hare aenghenomen dochters noch veel zyn geweest, als blijckt uyt die, de welcke de Weerdige Jouffrouwen my hebben gelieven schriftelijck soo in handen te gheven, als over te seynden, soo magh ick vryelijck seggen, dat waert saecken alle de opper Oversten den selven iver hadden, den welcken ick in de sommige gemerkt hebbe, dat wy haest een volle'), CheeseInText(explanation='The sentence does not contain any references to cheese or related topics. It discusses a legend and mentions individuals, but does not relate to cheese production, consumption, or cultural significance in the context of your research.', judgement=False, original_sentence='wy haest een volle legende van lofweerdige Beggyntjens by een souden hebben. Wel is waer dat jemant bequamer als ick, beter dit voornemen begost van den voorseyden Seer Eerw: Abt, soude hebben uytgewerckt: even-wel mits men maer en can aerbeyden, dan volgens sijne crachten, ende de mijne seer cleyn en verre beneden zyn aen de macht en iver die Godt gegeven heeft, soo aen den meer gemelden Edelen'), CheeseInText(explanation='The se ...

# %%
from dbnl_bear import overview

# %%
all_passages = [e.original_sentence for e in result]
relevant_passages = [e.original_sentence for e in result if e.judgement]

# %%
print("All passages:", len(all_passages))
print("Relevant passages:", len(relevant_passages))
# Out:
# All passages: 2986
# Relevant passages: 3

# %%
highlight_relevant_passages("dbnl_txt_files/_lev021leve01.txt", "test.docx", relevant_passages)
# Out:
# Processing passages: 100%|██████████| 167/167 [00:12<00:00, 13.06it/s]

# %%
buh = [e for e in result if e.judgement]

# %%
buh
# Out:
# [CheeseInText(explanation='The sentence discusses fasting practices during Lent (Vastens) and Advent, mentioning abstaining from meat (Vleesch) and dairy (zuivel), which may suggest a connection to cheese as it is a dairy product. However, it does not specifically mention cheese itself, so it is indirectly relevant to the study of cultural practices around food, including cheese.', judgement=True, original_sentence="Nu opgewassen en gecomen tot hare jaren, soude sy geeren arme Clarisse geworden hebben, en heeft somwylen heele Vastens en Adventen overgebrocht sonder Vleesch oft zuyvel te proeven, in alle die occasien van wel te connen en mogen eten, gelijk als 't in de groote Uytspanningen gaet, noch en dronk ook geen goet bier oft wyn, om haer selven te beproeven. Maer naer een doodelijke ziekte, soo"),
#  CheeseInText(explanation='The sentence discusses the act of drinking buttermilk, which is a dairy product related to cheese production. However, it does not explicitly mention cheese itself, focusing instead on buttermilk and a transaction involving it.', judgement=True, original_sentence="te coop en quam: sy naer haer gewoonelijke dienstbaerheyt nam den stoop op, ende gonk naer de stadt om melk in de Zele straet by een groenwaer-vrouw, de welke haer geriefde, ende presenteerde haer vers botermelk te drinken. Suster Marie nam het aen, ende dronk, gaf de Vrouw naer haer goet dunken een oort oft halven stuyver, maer de Vrouwe en accepteerde het gelt niet. Sy met de soete melk t'huys"),
#  CheeseInText(explanation="The sentence discusses a character named Anna Proters who is accused of witchcraft, involving butter and milk. While it doesn't directly mention cheese, butter and milk are related dairy products, which could be of interest when studying cheese in cultural contexts.", judgement=True, original_sentence="Het is dan geschiedt, dat 'er een Tooveresse met name Anna Proters de justitie is over gegeven, de welke was de selve groenwaer-vrouw daer Sr. Marie het boter-melk hadt by gedronken, de welke belijdende hare bedreven boosheden, beklaegde onder ander, dat sy een Beggyntjen van het groot Beggyn-hof alhier, hadde betoovert met eenen gierhonger, over seven jaer door boter-melk die sy haer te drinken")]

# %%
create_barcode_plot("test.png", relevant_passages, all_passages)

# %%
[1 if p in relevant_passages else 0 for p in all_passages]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 [1 if p in relevant_passages else 0 for p in all_passages]
#
# NameError: name 'all_passages' is not defined
